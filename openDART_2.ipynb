# %% [markdown]
# <a href="https://colab.research.google.com/github/aettikang/DataAnalysisPlan/blob/main/openDART.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install OpenDartReader
# Out:
# Collecting OpenDartReader
#   Downloading OpenDartReader-0.2.3-py3-none-any.whl.metadata (913 bytes)
# Requirement already satisfied: pandas>=0.19.2 in /usr/local/lib/python3.11/dist-packages (from OpenDartReader) (2.2.2)
# Requirement already satisfied: requests>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from OpenDartReader) (2.32.3)
# Collecting requests-file (from OpenDartReader)
#   Downloading requests_file-2.1.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.11/dist-packages (from OpenDartReader) (5.4.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from OpenDartReader) (4.13.4)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.19.2->OpenDartReader) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.19.2->OpenDartReader) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.19.2->OpenDartReader) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.19.2->OpenDartReader) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.3.0->OpenDartReader) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.3.0->OpenDartReader) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.3.0->OpenDartReader) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.3.0->OpenDartReader) (2025.4.26)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->OpenDartReader) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->OpenDartReader) (4.13.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=0.19.2->OpenDartReader) (1.17.0)
# Downloading OpenDartReader-0.2.3-py3-none-any.whl (27 kB)
# Downloading requests_file-2.1.0-py2.py3-none-any.whl (4.2 kB)
# Installing collected packages: requests-file, OpenDartReader
# Successfully installed OpenDartReader-0.2.3 requests-file-2.1.0

# %%
# 필요한 라이브러리를 불러옵니다.
import OpenDartReader
import pandas as pd
import os

# DART API 키 설정
api_key = '18e774f472941bee59d89cc43b47ab046dea27bf'  # 여기에 실제 API 키를 입력하세요.

# OpenDartReader 객체 생성
dart = OpenDartReader(api_key)

# 삼성전자의 재무제표 데이터 추출
# 삼성전자의 종목 코드는 '005930'입니다.
corp_code = '005930'  # 삼성전자의 종목 코드
year = 2022  # 사업보고서 연도 설정

# 사업보고서 내의 재무제표 섹션을 가져옵니다. 예: 'bs'는 재무상태표, 'is'는 손익계산서를 의미합니다.
# 여기서는 'bs' (재무상태표)를 예로 듭니다. 반환형태는 DataFrame입니다.
fs = dart.finstate_all(corp_code, year, fs_div='CFS', reprt_code='11011')

# fs 변수를 출력하여 결과를 확인합니다.
print(fs)

file_path = 'samsung_financials_2022.xlsx'
try:
    fs.to_excel(file_path, index=False)
    print(f"Saved successfully in {os.path.abspath(file_path)}")
except Exception as e:
    print("Failed to save:", e)
# Out:
# reprt_code='11011', fs_div='CFS' (사업보고서, 연결제무제표)'
#            rcept_no reprt_code bsns_year corp_code sj_div  sj_nm  \
# 0    20230307000542      11011      2022  00126380     BS  재무상태표
# 1    20230307000542      11011      2022  00126380     BS  재무상태표
# 2    20230307000542      11011      2022  00126380     BS  재무상태표
# 3    20230307000542      11011      2022  00126380     BS  재무상태표
# 4    20230307000542      11011      2022  00126380     BS  재무상태표
# ..              ...        ...       ...       ...    ...    ...
# 180  20230307000542      11011      2022  00126380    SCE  자본변동표
# 181  20230307000542      11011      2022  00126380    SCE  자본변동표
# 182  20230307000542      11011      2022  00126380    SCE  자본변동표
# 183  20230307000542      11011      2022  00126380    SCE  자본변동표
# 184  20230307000542      11011      2022  00126380    SCE  자본변동표
#
#                                             account_id       account_nm  \
# 0                              ifrs-full_CurrentAssets             유동자산
# 1                     ifrs-full_CashAndCashEquivalents         현금및현금성자산
# 2    dart_ShortTermDepositsNotClassifiedAsCashEquiv...           단기금융상품
# 3                                         -표준계정코드 미사용-      단기상각후원가금융자산
# 4    ifrs-full_CurrentFinancialAssetsAtFairValueThr...  단기당기손익-공정가치금융자산
# ..                                                 ...              ...
# 180                                   ifrs-full_Equity             기말자본
# 181                                   ifrs-full_Equity             기말자본
# 182                                   ifrs-full_Equity             기말자본
# 183                                   ifrs-full_Equity             기말자본
# 184                                   ifrs-full_Equity             기말자본
#
#                             account_detail thstrm_nm    thstrm_amount  \
# 0                                        -    제 54 기  218470581000000
# 1                                        -    제 54 기   49680710000000
# 2                                        -    제 54 기   65102886000000
# 3                                        -    제 54 기     414610000000
# 4                                        -    제 54 기      29080000000
# ..                                     ...       ...              ...
# 180          자본 [member]|지배기업 소유주지분|기타자본항목    제 54 기    1938328000000
# 181                 자본 [member]|지배기업 소유주지분    제 54 기  345186142000000
# 182             자본 [member]|비지배지분 [member]    제 54 기    9563462000000
# 183                        연결재무제표 [member]    제 54 기  354749604000000
# 184  자본 [member]|지배기업 소유주지분|이익잉여금 [member]    제 54 기  337946407000000
#
#     frmtrm_nm    frmtrm_amount bfefrmtrm_nm bfefrmtrm_amount ord currency  \
# 0      제 53 기  218163185000000       제 52 기  198215579000000   1      KRW
# 1      제 53 기   39031415000000       제 52 기   29382578000000   2      KRW
# 2      제 53 기   81708986000000       제 52 기   92441703000000   3      KRW
# 3      제 53 기    3369034000000       제 52 기    2757111000000   4      KRW
# 4      제 53 기      40757000000       제 52 기      71451000000   5      KRW
# ..        ...              ...          ...              ...  ..      ...
# 180    제 53 기   -2128473000000       제 52 기   -8687155000000  13      KRW
# 181    제 53 기  296237697000000       제 52 기  267670331000000  13      KRW
# 182    제 53 기    8662234000000       제 52 기    8277685000000  13      KRW
# 183    제 53 기  304899931000000       제 52 기  275948016000000  13      KRW
# 184    제 53 기  293064763000000       제 52 기  271068211000000  13      KRW
#
#     thstrm_add_amount
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ..                ...
# 180               NaN
# 181               NaN
# 182               NaN
# 183               NaN
# 184               NaN
#
# [185 rows x 18 columns]
# Saved successfully in /content/samsung_financials_2022.xlsx

# %%
import yfinance as yf
import matplotlib.pyplot as plt

# 삼성전자의 티커 심볼
ticker_symbol = '005930.KS'

# yfinance를 사용하여 삼성전자의 주가 데이터를 가져옵니다.
samsung = yf.Ticker(ticker_symbol)

# 2023년 1월 1일부터 2024년 3월 10일까지의 주가 데이터를 가져옵니다.
start_date = '2023-01-01'
end_date = '2024-03-10'
hist = samsung.history(start=start_date, end=end_date)

# 종가 데이터를 시각화합니다.
plt.figure(figsize=(14, 7))  # 그래프 크기 설정
plt.plot(hist.index, hist['Close'], label='Close Price')  # 종가 그래프를 그립니다.
plt.title('Samsung Electronics Close Price from 2023-01-01 to 2024-03-10')  # 그래프 제목 설정
plt.xlabel('Date')  # x축 레이블 설정
plt.ylabel('Close Price (KRW)')  # y축 레이블 설정
plt.legend()  # 범례 표시
plt.grid(True)  # 그리드 표시
plt.show()  # 그래프 표시
# Out:
# ---------------------------------------------------------------------------
# YFRateLimitError                          Traceback (most recent call last)
# <ipython-input-3-11c4389baba6> in <cell line: 0>()
#      11 start_date = '2023-01-01'
#      12 end_date = '2024-03-10'
# ---> 13 hist = samsung.history(start=start_date, end=end_date)
#      14
#      15 # 종가 데이터를 시각화합니다.
#
# /usr/local/lib/python3.11/dist-packages/yfinance/utils.py in wrapper(*args, **kwargs)
#     101
#     102         with IndentationContext():
# --> 103             result = func(*args, **kwargs)
#     104
#     105         logger.debug(f'Exiting {func.__name__}()')
#
# /usr/local/lib/python3.11/dist-packages/yfinance/base.py in history(self, *args, **kwargs)
#      89     @utils.log_indent_decorator
#      90     def history(self, *args, **kwargs) -> pd.DataFrame:
# ---> 91         return self._lazy_load_price_history().history(*args, **kwargs)
#      92
#      93     # ------------------------
#
# /usr/local/lib/python3.11/dist-packages/yfinance/base.py in _lazy_load_price_history(self)
#      95     def _lazy_load_price_history(self):
#      96         if self._price_history is None:
# ---> 97             self._price_history = PriceHistory(self._data, self.ticker, self._get_ticker_tz(timeout=10))
#      98         return self._price_history
#      99
#
# /usr/local/lib/python3.11/dist-packages/yfinance/base.py in _get_ticker_tz(self, timeout)
#     110
#     111         if tz is None:
# --> 112             tz = self._fetch_ticker_tz(timeout)
#     113             if tz is None:
#     114                 # _fetch_ticker_tz works in 99.999% of cases.
#
# /usr/local/lib/python3.11/dist-packages/yfinance/utils.py in wrapper(*args, **kwargs)
#     101
#     102         with IndentationContext():
# --> 103             result = func(*args, **kwargs)
#     104
#     105         logger.debug(f'Exiting {func.__name__}()')
#
# /usr/local/lib/python3.11/dist-packages/yfinance/base.py in _fetch_ticker_tz(self, timeout)
#     142
#     143         try:
# --> 144             data = self._data.cache_get(url=url, params=params, timeout=timeout)
#     145             data = data.json()
#     146         except YFRateLimitError:
#
# /usr/local/lib/python3.11/dist-packages/yfinance/data.py in wrapped(*args, **kwargs)
#      30         args = tuple([tuple(arg) if isinstance(arg, list) else arg for arg in args])
#      31         kwargs = {k: tuple(v) if isinstance(v, list) else v for k, v in kwargs.items()}
# ---> 32         return func(*args, **kwargs)
#      33
#      34     # copy over the lru_cache extra methods to this wrapper to be able to access them
#
# /usr/local/lib/python3.11/dist-packages/yfinance/data.py in cache_get(self, url, user_agent_headers, params, timeout)
#     429     @lru_cache(maxsize=cache_maxsize)
#     430     def cache_get(self, url, user_agent_headers=None, params=None, timeout=30):
# --> 431         return self.get(url, user_agent_headers, params, timeout)
#     432
#     433     def get_raw_json(self, url, user_agent_headers=None, params=None, timeout=30):
#
# /usr/local/lib/python3.11/dist-packages/yfinance/utils.py in wrapper(*args, **kwargs)
#     101
#     102         with IndentationContext():
# --> 103             result = func(*args, **kwargs)
#     104
#     105         logger.debug(f'Exiting {func.__name__}()')
#
# /usr/local/lib/python3.11/dist-packages/yfinance/data.py in get(self, url, user_agent_headers, params, timeout)
#     362     @utils.log_indent_decorator
#     363     def get(self, url, user_agent_headers=None, params=None, timeout=30):
# --> 364         return self._make_request(url, request_method = self._session.get, user_agent_headers=user_agent_headers, params=params, timeout=timeout)
#     365
#     366     @utils.log_indent_decorator
#
# /usr/local/lib/python3.11/dist-packages/yfinance/utils.py in wrapper(*args, **kwargs)
#     101
#     102         with IndentationContext():
# --> 103             result = func(*args, **kwargs)
#     104
#     105         logger.debug(f'Exiting {func.__name__}()')
#
# /usr/local/lib/python3.11/dist-packages/yfinance/data.py in _make_request(self, url, request_method, user_agent_headers, body, params, timeout)
#     422             # Raise exception if rate limited
#     423             if response.status_code == 429:
# --> 424                 raise YFRateLimitError()
#     425
#     426         return response
#
# YFRateLimitError: Too Many Requests. Rate limited. Try after a while.

# %%
import yfinance as yf
import matplotlib.pyplot as plt
import pandas as pd

# 삼성전자와 삼성에스디에스의 티커 심볼 설정
symbols = ['005930.KS', '018260.KS']  # 삼성전자: '005930.KS', 삼성에스디에스: '018260.KS'

# 주가 데이터 가져오기
start_date = '2023-01-01'
end_date = '2024-03-10'
samsung_electronics = yf.download('005930.KS', start=start_date, end=end_date)['Close']
samsung_sds = yf.download('018260.KS', start=start_date, end=end_date)['Close']

# 데이터프레임 합치기
df = pd.DataFrame({'Samsung Electronics': samsung_electronics, 'Samsung SDS': samsung_sds})

# 상관계수 계산
rolling_correlation = df['Samsung Electronics'].rolling(window=30).corr(df['Samsung SDS'])

# 상관계수가 0.85 이상인 기간 찾기
high_corr_periods = rolling_correlation >= 0.60

# 그래프 그리기
plt.figure(figsize=(14, 7))

# 삼성전자 종가 그래프
plt.plot(df.index, df['Samsung Electronics'], label='Samsung Electronics Close Price', color='blue')

# 삼성에스디에스 종가 그래프
plt.plot(df.index, df['Samsung SDS'], label='Samsung SDS Close Price', color='green')

# 상관계수가 0.85 이상인 기간 표시
plt.fill_between(df.index, df['Samsung Electronics'].min(), df['Samsung Electronics'].max(),
                 where=high_corr_periods, color='gray', alpha=0.3, label='High Correlation (>=0.85)')

plt.title('Samsung Electronics and Samsung SDS Close Price with High Correlation Periods')
plt.xlabel('Date')
plt.ylabel('Close Price (KRW)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['005930.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['018260.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-5d223ddbe7c8> in <cell line: 0>()
#      13
#      14 # 데이터프레임 합치기
# ---> 15 df = pd.DataFrame({'Samsung Electronics': samsung_electronics, 'Samsung SDS': samsung_sds})
#      16
#      17 # 상관계수 계산
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     776         elif isinstance(data, dict):
#     777             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 778             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     779         elif isinstance(data, ma.MaskedArray):
#     780             from numpy.ma import mrecords
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/internals/construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     501             arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
#     502
# --> 503     return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#     504
#     505
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     112         # figure out the index, if necessary
#     113         if index is None:
# --> 114             index = _extract_index(arrays)
#     115         else:
#     116             index = ensure_index(index)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/internals/construction.py in _extract_index(data)
#     665
#     666     if not indexes and not raw_lengths:
# --> 667         raise ValueError("If using all scalar values, you must pass an index")
#     668
#     669     if have_series:
#
# ValueError: If using all scalar values, you must pass an index

# %%
# !pip install finance-datareader
# Out:
# Collecting finance-datareader
#   Downloading finance_datareader-0.9.96-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from finance-datareader) (4.13.4)
# Requirement already satisfied: lxml in /usr/local/lib/python3.11/dist-packages (from finance-datareader) (5.4.0)
# Requirement already satisfied: pandas>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from finance-datareader) (2.2.2)
# Requirement already satisfied: plotly in /usr/local/lib/python3.11/dist-packages (from finance-datareader) (5.24.1)
# Requirement already satisfied: requests-file in /usr/local/lib/python3.11/dist-packages (from finance-datareader) (2.1.0)
# Requirement already satisfied: requests>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from finance-datareader) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from finance-datareader) (4.67.1)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.0->finance-datareader) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.0->finance-datareader) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.0->finance-datareader) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.0->finance-datareader) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.3.0->finance-datareader) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.3.0->finance-datareader) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.3.0->finance-datareader) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.3.0->finance-datareader) (2025.4.26)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->finance-datareader) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->finance-datareader) (4.13.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly->finance-datareader) (9.1.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from plotly->finance-datareader) (24.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=1.1.0->finance-datareader) (1.17.0)
# Downloading finance_datareader-0.9.96-py3-none-any.whl (48 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.2/48.2 kB 3.2 MB/s eta 0:00:00
# Installing collected packages: finance-datareader
# Successfully installed finance-datareader-0.9.96

# %%
import FinanceDataReader as fdr
# KOSPI 상장 종목 목록 불러오기
kospi_list = fdr.StockListing('KOSPI')

# 종목 코드 추출 및 각 코드에 '.KS' 접미사 추가
kospi_tickers = [code + '.KS' for code in kospi_list['Code']]
print(kospi_tickers[:5])
# Out:
# ['005930.KS', '000660.KS', '207940.KS', '373220.KS', '005380.KS']

# %%
#KOSDAK 종목도 비교
# KOSPI 상장 종목 목록 불러오기
kosdak_list = fdr.StockListing('KOSDAQ')

# 종목 코드 추출 및 각 코드에 '.KS' 접미사 추가
kosdaq_tickers = [code + '.KS' for code in kospi_list['Code']]
print(kosdaq_tickers[:5])
# Out:
# ['005930.KS', '000660.KS', '207940.KS', '373220.KS', '005380.KS']

# %%
import yfinance as yf
import pandas as pd

# 코스피 종목 코드 리스트 (예시)
#kospi_tickers = ['005930.KS', '000660.KS', '035420.KS']  # 실제로는 모든 코스피 종목 코드를 포함해야 합니다.

# 종가 데이터를 저장할 데이터프레임 생성
# 각 종목의 주가 데이터 다운로드 및 DataFrame으로 합치기
data_frames = []
for ticker in kospi_tickers:
    data = yf.download(ticker, start=start_date, end=end_date)['Close']
    data_frames.append(data.rename(ticker))

close_prices = pd.concat(data_frames, axis=1)

# 삼성전자와 다른 종목들 간의 상관계수 계산
correlations = close_prices.corr().loc['005930.KS'].sort_values(ascending=False)

# 상관계수가 높은 상위 5개 종목 출력 (삼성전자 자신 제외)
print(correlations[1:6])
# Out:
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['005930.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['000660.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['207940.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['373220.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['005380.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['012450.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['005935.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['105560.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['329180.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['068270.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['000270.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['035420.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['055550.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['042660.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['012330.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['138040.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['028260.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['005490.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['009540.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['259960.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['086790.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['000810.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['034020.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['032830.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['035720.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['015760.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['010130.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['011200.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['051910.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['033780.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['096770.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['030200.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['316140.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['010140.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['064350.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['024110.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['402340.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['006400.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['267260.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['066570.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['017670.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['352820.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['323410.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['003550.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['018260.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['003670.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['034730.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['000100.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['009150.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['047050.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['326030.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['047810.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['086280.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['272210.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['003490.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['003230.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['042700.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['090430.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['079550.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['010620.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['443060.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['006800.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['005830.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['010120.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['021240.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['267250.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['010950.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['088980.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['000150.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['005387.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['180640.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['032640.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['051900.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['009830.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['161390.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['064400.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['005940.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['271560.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['029780.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['298040.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['016360.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['241560.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['071050.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['000720.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['377300.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['034220.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['006260.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['251270.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['011790.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['450080.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['028050.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['022100.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['001040.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['000880.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['097950.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['005385.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['078930.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['036460.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['035250.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['307950.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['128940.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['039490.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['175330.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['138930.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['004020.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['011070.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['454910.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['462870.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['036570.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['302440.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['011780.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['489790.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['017800.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['278470.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['383220.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['007660.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['026960.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['011170.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['052690.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['031210.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['139480.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['004370.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['012750.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['004990.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['018880.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['066970.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['082740.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['088350.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['081660.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['002380.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['001440.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['018670.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['030000.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['111770.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['192820.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['001450.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['008930.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['051600.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['020560.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['023530.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['012510.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['000120.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['282330.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['002790.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['161890.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['028670.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['204320.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['062040.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['008770.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['000990.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['139130.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['294870.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['069620.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['006040.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['103140.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['375500.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['042670.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['361610.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['112610.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['007310.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['003690.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['001720.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['005850.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['004170.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['006360.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['047040.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['009420.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['006280.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['000240.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['395400.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['000080.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['073240.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['069960.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['457190.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['014680.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['009970.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['071970.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['005070.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['103590.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['300720.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['267270.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['007070.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['010060.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['192080.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['007340.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['020150.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['003090.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['001800.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['137310.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['011210.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['012630.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['034230.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['185750.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['003570.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['009450.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['280360.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['089860.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['330590.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['365550.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['298020.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['001120.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['017960.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['005300.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['000500.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['009240.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['229640.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['336260.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['004490.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['009410.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['077970.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['082640.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['003030.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['023590.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['014820.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['484870.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['415640.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['085620.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['001740.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['005180.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['000815.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['003540.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['002840.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['004000.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['108320.KS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-a1e4dda07a0f> in <cell line: 0>()
#       9 data_frames = []
#      10 for ticker in kospi_tickers:
# ---> 11     data = yf.download(ticker, start=start_date, end=end_date)['Close']
#      12     data_frames.append(data.rename(ticker))
#      13
#
# /usr/local/lib/python3.11/dist-packages/yfinance/utils.py in wrapper(*args, **kwargs)
#     101
#     102         with IndentationContext():
# --> 103             result = func(*args, **kwargs)
#     104
#     105         logger.debug(f'Exiting {func.__name__}()')
#
# /usr/local/lib/python3.11/dist-packages/yfinance/multi.py in download(tickers, start, end, actions, threads, ignore_tz, group_by, auto_adjust, back_adjust, repair, keepna, progress, period, interval, prepost, proxy, rounding, timeout, session, multi_level_index)
#     162                                    rounding=rounding, timeout=timeout)
#     163         while len(shared._DFS) < len(tickers):
# --> 164             _time.sleep(0.01)
#     165     # download synchronously
#     166     else:
#
# KeyboardInterrupt:

# %%
import yfinance as yf
import pandas as pd
import FinanceDataReader as fdr

def get_top_correlated_tickers_with_concat(market_type, top_n=10):
    """
    주어진 시장의 상장 종목 중 삼성전자(005930.KS)와 상관계수가 높은 상위 n개 종목을 찾습니다.
    이번에는 pd.concat()을 사용하여 DataFrame의 파편화를 방지합니다.

    Parameters:
    - market_type: 'KOSPI' 또는 'KOSDAQ' 중 하나를 지정합니다.
    - top_n: 반환할 상위 종목의 개수입니다.

    Returns:
    - 상관계수가 높은 상위 n개 종목의 코드와 상관계수를 포함하는 DataFrame.
    """
    # 시장 종목 코드 리스트 가져오기
    market_list = fdr.StockListing(market_type)
    tickers = market_list['Code'].apply(lambda x: x + '.KS' if market_type == 'KOSPI' else x + '.KQ').tolist()
    if '005930.KS' not in tickers:
        tickers.append('005930.KS')

    # 각 종목의 주가 데이터 다운로드
    data_frames = []
    for ticker in tickers:
        try:
            data = yf.download(ticker, start='2023-01-01', end='2024-03-10')['Close'].rename(ticker)
            data_frames.append(data)
        except Exception as e:
            print(f"Error downloading {ticker}: {e}")

    # 모든 주가 데이터를 하나의 DataFrame으로 합치기
    close_prices = pd.concat(data_frames, axis=1)

    # 삼성전자와 다른 종목들 간의 상관계수 계산
    correlations = close_prices.corr().loc['005930.KS'].sort_values(ascending=False)

    # 상관계수가 높은 상위 n개 종목 반환 (삼성전자 제외)
    return correlations[1:top_n+1]

# KOSPI 시장에서 삼성전자와 상관계수가 높은 상위 5개 종목 찾기
top_correlated_kospi = get_top_correlated_tickers_with_concat('KOSDAQ')
print("KOSPI:", top_correlated_kospi)
# Out:
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['196170.KQ']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['247540.KQ']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['028300.KQ']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['086520.KQ']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['277810.KQ']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['145020.KQ']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['214150.KQ']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['214450.KQ']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['087010.KQ']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['141080.KQ']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['000250.KQ']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['298380.KQ']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['950160.KQ']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['041510.KQ']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['058470.KQ']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['035900.KQ']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['263750.KQ']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['257720.KQ']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['068760.KQ']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['403870.KQ']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['310210.KQ']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['007390.KQ']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['348370.KQ']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['065350.KQ']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['036930.KQ']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['237690.KQ']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['253450.KQ']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['005290.KQ']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['328130.KQ']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-9cde0a72d48e> in <cell line: 0>()
#      40
#      41 # KOSPI 시장에서 삼성전자와 상관계수가 높은 상위 5개 종목 찾기
# ---> 42 top_correlated_kospi = get_top_correlated_tickers_with_concat('KOSDAQ')
#      43 print("KOSPI:", top_correlated_kospi)
#
# <ipython-input-10-9cde0a72d48e> in get_top_correlated_tickers_with_concat(market_type, top_n)
#      25     for ticker in tickers:
#      26         try:
# ---> 27             data = yf.download(ticker, start='2023-01-01', end='2024-03-10')['Close'].rename(ticker)
#      28             data_frames.append(data)
#      29         except Exception as e:
#
# /usr/local/lib/python3.11/dist-packages/yfinance/utils.py in wrapper(*args, **kwargs)
#     101
#     102         with IndentationContext():
# --> 103             result = func(*args, **kwargs)
#     104
#     105         logger.debug(f'Exiting {func.__name__}()')
#
# /usr/local/lib/python3.11/dist-packages/yfinance/multi.py in download(tickers, start, end, actions, threads, ignore_tz, group_by, auto_adjust, back_adjust, repair, keepna, progress, period, interval, prepost, proxy, rounding, timeout, session, multi_level_index)
#     162                                    rounding=rounding, timeout=timeout)
#     163         while len(shared._DFS) < len(tickers):
# --> 164             _time.sleep(0.01)
#     165     # download synchronously
#     166     else:
#
# KeyboardInterrupt:
